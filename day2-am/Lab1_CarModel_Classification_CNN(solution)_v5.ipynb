# %% [markdown]
# ![image](https://drive.google.com/uc?id=1iBMNGCrSdaLK9SD6BjsuNjB1DjHVkLZl)
#
# Welcome to the Colab! Before we get started here are a few pointers on Colab notebooks.
#
# 1. The notebook is composed of cells; cells can contain code which you can run by click on the play button.
#
#
# 2. To interrupt cell execution, click the ```Stop``` button on the side of the cell.

# %% [markdown]
# # Lab 1(solution) : Car Model Classification with CNN
# In this lab we will try to build a Vehicle Classifier to classify three different models of the car. We will collect 3 groups of images namely  Honda Civic, Toyota Altis and Volkswagen Passat to be our dataset. The  collected dataset will be used to train the Resnet50 CNN(Convolution Neural Network). Upon completion of the training, we will be able to classify an unknown image to give a prediction of the model of the car.
#
#
# We will build the car model classifier based on the following steps
#
# 1.   Colab python virtual environment
# 2.   Import the libraries needed for the program
# 3.  Prepare the data
# 4.   Prepare the CNN model
# 5.  Train the model with the training set and evaluate its performance
# 6.   Use the trained model to classify input data

# %% [markdown]
# # 1. Colab python virtual environment
#
# Colab is preinstalled with python virtual environment with the Tensorflow2.
# We will use this default virtual environment for the execrise.

# %% [markdown]
# # 2. Import the libraries needed for the program
# We will begin by importing the libraries that we need, mainly Keras.
# Keras is based on a minimal framework that provides a simpler way to create deep learning models based on TensorFlow.
# Keras contains useful functions for pre-preprocessing of image data and definition of convolution neural network.
# Matplotlib is used for data visualization.

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions

# %%
print(tensorflow.__version__)
# Out:
# 2.14.0

# %% [markdown]
# # 3. Prepare the data
#
# Usually in ML, we divide our data into 3 different sets
#
# - Training Data: Collection of sample data used to train the neural network.
#
# - Validation Data: Collection of sample data used to provide an unbiased evaluation of neural netowork during the training.
#
# - Test Data: Collection of sample data used to evaluate the trained neural network.

# %% [markdown]
# ### 3.1 Collect data for training and validation
#
# We have pre-collected data that are stored in the following directory structure.
#
# For train data, it is stored in the path ./Lab1dataset/data/train.
# ```
# ./Lab1dataset/data/train
#                            |- Honda
#                            |- Toyota
#                            |- Volkswagen
#
# ```
# Each of the above sub-directories(Honda, Toyota, Volkawagen) is stored with
# 60 different jpg images.
#
#
# For validation data, it is stored in the path ./Lab1dataset/data/validation.
# ```
# ./Lab1dataset/data/validation.
#                                |- Honda
#                                |- Toyota
#                                |- Volkswagen
# ```
# Each of the above sub-directories(Honda, Toyota, Volkawagen) is stored with
# 15 different jpg images.
#
#
# For test data, it is stored in the path /Lab1dataset/prediction_images
# ```
# ./Lab1dataset/
#     |- prediction_images
#
# ```
# A few test images are stored in the above test directory.
#
# Download the data and unzip it.

# %%
# !wget https://nyp-aicourse.s3-ap-southeast-1.amazonaws.com/aiup/day2-am/Lab1dataset.zip
# !unzip Lab1dataset.zip
# Out:
# --2023-11-17 03:14:57--  https://nyp-aicourse.s3-ap-southeast-1.amazonaws.com/aiup/day2-am/Lab1dataset.zip
# Resolving nyp-aicourse.s3-ap-southeast-1.amazonaws.com (nyp-aicourse.s3-ap-southeast-1.amazonaws.com)... 3.5.150.171, 52.219.164.138, 52.219.164.146, ...
# Connecting to nyp-aicourse.s3-ap-southeast-1.amazonaws.com (nyp-aicourse.s3-ap-southeast-1.amazonaws.com)|3.5.150.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 710866112 (678M) [application/zip]
# Saving to: ‘Lab1dataset.zip’
#
# Lab1dataset.zip     100%[===================>] 677.93M  21.2MB/s    in 33s
#
# 2023-11-17 03:15:31 (20.3 MB/s) - ‘Lab1dataset.zip’ saved [710866112/710866112]
#
# Archive:  Lab1dataset.zip
#    creating: Lab1dataset/
#    creating: Lab1dataset/data/
#    creating: Lab1dataset/data/train/
#    creating: Lab1dataset/data/train/Honda/
#   inflating: Lab1dataset/data/train/Honda/100.jpg
#   inflating: Lab1dataset/data/train/Honda/11105_m.jpg
#   inflating: Lab1dataset/data/train/Honda/11875_m.jpg
#   inflating: Lab1dataset/data/train/Honda/16_Civic_Sedan_044.jpg
#   inflating: Lab1dataset/data/train/Honda/199034_new_honda_civic_sport_line_delivers_type_r-inspired_styling.jpg
#   inflating: Lab1dataset/data/train/Honda/2.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-Honda-Civic-Hatchback-Review-0004.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-Honda-Civic-Rear.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-Honda-Civic-Sedan-Rochester-NY-Silver-LX-1.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-honda-civic-si-coupe-and-sedan-045-1573243367.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-honda-civic-sport-manual-angular-front-exterior-view_100751892_l.jpg
#   inflating: Lab1dataset/data/train/Honda/2020-honda-civic-type-r-sport-line.jpg
#   inflating: Lab1dataset/data/train/Honda/2020HondaCivicVTi-LXhatch(24).jpg
#   inflating: Lab1dataset/data/train/Honda/2020_honda_civic_angularfront.jpg
#   inflating: Lab1dataset/data/train/Honda/24fa043ae3adeec41ae9cc166886f28c.jpg
#   inflating: Lab1dataset/data/train/Honda/59e40373a4247c71b0860be7566d3fdf.jpg
#   inflating: Lab1dataset/data/train/Honda/6478385_00964_25cd9b87-91b3-4040-b048-bceec0fc104e.jpg
#   inflating: Lab1dataset/data/train/Honda/70005202163020091600100.jpg
#   inflating: Lab1dataset/data/train/Honda/70944463-8dbd-40ce-8e01-7ee72a647650-copy.jpg
#   inflating: Lab1dataset/data/train/Honda/9tro-2019-honda-civic-3.jpg
#  extracting: Lab1dataset/data/train/Honda/BT_20190719__JLHONDA19_3839459.jpg
#   inflating: Lab1dataset/data/train/Honda/cIkLZpuR-770x430.jpg
#   inflating: Lab1dataset/data/train/Honda/Civic_LX.jpg
#   inflating: Lab1dataset/data/train/Honda/download (1).jpg
#   inflating: Lab1dataset/data/train/Honda/download (2).jpg
#   inflating: Lab1dataset/data/train/Honda/download (3).jpg
#   inflating: Lab1dataset/data/train/Honda/download.jpg
#   inflating: Lab1dataset/data/train/Honda/DSC04356.jpg
#   inflating: Lab1dataset/data/train/Honda/exterior-2-2.jpg
#   inflating: Lab1dataset/data/train/Honda/hond-civic-15-1.jpg
#   inflating: Lab1dataset/data/train/Honda/honda-civic-color-230235.jpg
#   inflating: Lab1dataset/data/train/Honda/honda-civic-front-tracking.jpg
#   inflating: Lab1dataset/data/train/Honda/honda-civic-hatchback-cars-and-coffee-singapore-4.jpg
#   inflating: Lab1dataset/data/train/Honda/honda-civic-road-test-exterior-beauty-philippines-5d9ed003eed56.jpg
#  extracting: Lab1dataset/data/train/Honda/Honda-Civic-Sedan-LX_1.png
#   inflating: Lab1dataset/data/train/Honda/honda-civic-singapore-2008.jpg
#   inflating: Lab1dataset/data/train/Honda/Honda-Civic-Sport-2020.jpg
#   inflating: Lab1dataset/data/train/Honda/Honda-Civic-Turbo-1.5-2019-new-review-price-Singapore-10-1024x683(1).jpg
#   inflating: Lab1dataset/data/train/Honda/Honda-Civic-Turbo-1.5-2019-new-review-price-Singapore-10-1024x683.jpg
#  extracting: Lab1dataset/data/train/Honda/Honda-Civic2.0-01-watermark.jpg
#   inflating: Lab1dataset/data/train/Honda/honda_civic_turbo_rs_singapore.jpg
#   inflating: Lab1dataset/data/train/Honda/image1.jpg
#   inflating: Lab1dataset/data/train/Honda/images (1).jpg
#   inflating: Lab1dataset/data/train/Honda/images (10).jpg
#   inflating: Lab1dataset/data/train/Honda/images (11).jpg
#   inflating: Lab1dataset/data/train/Honda/images (12).jpg
#   inflating: Lab1dataset/data/train/Honda/images (13).jpg
#   inflating: Lab1dataset/data/train/Honda/images (14).jpg
#   inflating: Lab1dataset/data/train/Honda/images (2).jpg
#   inflating: Lab1dataset/data/train/Honda/images (3).jpg
#   inflating: Lab1dataset/data/train/Honda/images (4).jpg
#   inflating: Lab1dataset/data/train/Honda/images (9).jpg
#   inflating: Lab1dataset/data/train/Honda/images.jpg
#   inflating: Lab1dataset/data/train/Honda/img-9763-1590075401.jpg
#   inflating: Lab1dataset/data/train/Honda/l5gua92olkk9zsrkduea.jpg
#   inflating: Lab1dataset/data/train/Honda/maxresdefault.jpg
#   inflating: Lab1dataset/data/train/Honda/resized-20120205221432962.jpg
#  extracting: Lab1dataset/data/train/Honda/resized-20161208155436487.jpg
#   inflating: Lab1dataset/data/train/Honda/s19-1583120332-6918-honda-civic.jpg
#   inflating: Lab1dataset/data/train/Honda/singapore_automotive_photography_honda_civic_fk8_commercial_005.jpg
#   inflating: Lab1dataset/data/train/Honda/t0n6jpuyort5pv4uwfei.jpg
#   inflating: Lab1dataset/data/train/Honda/thumb.jpg
#    creating: Lab1dataset/data/train/Toyota/
#   inflating: Lab1dataset/data/train/Toyota/0613456875d746889df394cdedaafee9.jpg
#   inflating: Lab1dataset/data/train/Toyota/1585585843965main1.jpg
#  extracting: Lab1dataset/data/train/Toyota/1585703964550main1.jpg
#   inflating: Lab1dataset/data/train/Toyota/2020-toyota-corolla-altis-01-1568000742.jpg
#   inflating: Lab1dataset/data/train/Toyota/2020-Toyota-Corolla-Altis-Exterior-Singapore-Carbuyer.com_.sg-16.jpg
#   inflating: Lab1dataset/data/train/Toyota/2020-Toyota-Corolla-Altis-Terstudio-Drive68_11-e1586915609601-1200x629.jpg
#   inflating: Lab1dataset/data/train/Toyota/2020_toyota_corolla_altis_hybrid_00.jpg
#   inflating: Lab1dataset/data/train/Toyota/2182989.jpg
#   inflating: Lab1dataset/data/train/Toyota/22458_p1_s_2.jpg
#  extracting: Lab1dataset/data/train/Toyota/30822297.jpg
#   inflating: Lab1dataset/data/train/Toyota/4290.jpg
#   inflating: Lab1dataset/data/train/Toyota/897253_1.jpg
#   inflating: Lab1dataset/data/train/Toyota/8b849b370a794c12868412fc2fbae439.jpg
#  extracting: Lab1dataset/data/train/Toyota/8B98C814-9248-4784-A6A1-7B3BC93D75BF-620x350.jpg
#   inflating: Lab1dataset/data/train/Toyota/915789_1.jpg
#   inflating: Lab1dataset/data/train/Toyota/9tro-altis-club-singapore-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/ad6ae812722d40b8856af09464ad8f49.jpg
#   inflating: Lab1dataset/data/train/Toyota/Altis.jpg
#   inflating: Lab1dataset/data/train/Toyota/bc48099fd50bfd9a560f42b962d711cc.jpg
#   inflating: Lab1dataset/data/train/Toyota/bd9eb876ef97fc9dd6dba96d59b1535d.jpg
#   inflating: Lab1dataset/data/train/Toyota/BT_20150807_SECARS50A_1814138.jpg
#   inflating: Lab1dataset/data/train/Toyota/BT_20200124_TOYOTA24_401514.jpg
#   inflating: Lab1dataset/data/train/Toyota/download.jpg
#   inflating: Lab1dataset/data/train/Toyota/DSC_2474-1-1-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/EEA0103.jpg
#   inflating: Lab1dataset/data/train/Toyota/exterior_3.jpg
#   inflating: Lab1dataset/data/train/Toyota/featured-article_11250.jpg
#   inflating: Lab1dataset/data/train/Toyota/front-view.jpg
#   inflating: Lab1dataset/data/train/Toyota/images (1).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (2).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (5).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (6).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (7).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (8).jpg
#   inflating: Lab1dataset/data/train/Toyota/images (9).jpg
#   inflating: Lab1dataset/data/train/Toyota/images.jpg
#   inflating: Lab1dataset/data/train/Toyota/IMG_1293-2-1024x683-2.jpg
#   inflating: Lab1dataset/data/train/Toyota/maxresdefault (1).jpg
#   inflating: Lab1dataset/data/train/Toyota/maxresdefault.jpg
#   inflating: Lab1dataset/data/train/Toyota/motorist-mreview-toyota-corolla-altis-2020-to-buy-or-not-to-buy.jpg
#   inflating: Lab1dataset/data/train/Toyota/product-altis.jpg
#   inflating: Lab1dataset/data/train/Toyota/slider-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/slider-2.jpg
#   inflating: Lab1dataset/data/train/Toyota/Toyota Corolla Altis - 2.JPG
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-altis-11447.jpg
#   inflating: Lab1dataset/data/train/Toyota/Toyota-Corolla-Altis-2.0V-facelift-1 (1).jpg
#   inflating: Lab1dataset/data/train/Toyota/Toyota-Corolla-Altis-2.0V-facelift-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-altis-2019-color-207868.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-altis-2020-32eb5ac3.jpg
#   inflating: Lab1dataset/data/train/Toyota/TOYOTA-Corolla-Altis-5148_5.jpg
#  extracting: Lab1dataset/data/train/Toyota/toyota-corolla-altis-front-angle-low-view-476434.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-altis-hybrid-review-road-test-front-quarter-exterior-philippines-5de4a59f318b3.jpg
#  extracting: Lab1dataset/data/train/Toyota/toyota-corolla-altis-main-front.jpg
#   inflating: Lab1dataset/data/train/Toyota/Toyota-Corolla-Altis-New-2020-Singapore-Motorshow-CarBuyer.com_.sg-5.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-altis.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota-corolla-hybrid-review-2-1585297391.jpg
#   inflating: Lab1dataset/data/train/Toyota/toyota_corolla_altis_16a_classic_2015__low_mileage_great_condition_1552151011_4af6ed3b_progressive.jpg
#  extracting: Lab1dataset/data/train/Toyota/Toyota_Corolla_Altis_2017_facelift_singapore_4.jpg
#  extracting: Lab1dataset/data/train/Toyota/Toyota_Corolla_Altis_2017_facelift_singapore_6-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/Toyota_Corolla_Altis_2017_facelift_singapore_7-1.jpg
#   inflating: Lab1dataset/data/train/Toyota/which-variant-corolla-altis-5e4522c48d6c0.jpg
#    creating: Lab1dataset/data/train/Volkswagen/
#   inflating: Lab1dataset/data/train/Volkswagen/1 (1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/1.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/10692_m.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/11.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/11749_m.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-volkswagen-passat-front-view-driving-carbuzz-646956.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-volkswagen-passat-placement-1547422088.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-Volkswagen-Passat-Pure-White.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-Volkswagen-Passat-R-Line-Launch-Malaysia_Ext-1.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-volkswagen-passat-sedan-silver-1001x565-(2).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-VW-Passat-driver-front-927x640.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/2020-VW-Passat-US-spec-53.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/21099490651538447876.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/3.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/4.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/4222561461597672486629.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/4490.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/6ac2a413-2020-vw-passat-euro-spec-4.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/889820_2b.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/910192_3.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/914837_1b.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/917594_1.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/921567_2b.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/9aef125ed7d44f88a55ae95a0d49f4ee.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a1.jpg
#  extracting: Lab1dataset/data/train/Volkswagen/a2.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a3.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a4.jpg
#  extracting: Lab1dataset/data/train/Volkswagen/a5.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a6.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a7.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a8.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/a9.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/DB2014AU01105_small20copy.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/DB2019AU00090_large.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/download (1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/download.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/f8549111a8454e6cb21c20123af98fc1.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/featured-article_862.jpg
#  extracting: Lab1dataset/data/train/Volkswagen/front-left-side-47.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/image-1 (1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/image-1.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (10).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (11).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (12).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (13).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (14).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (15).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (2).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (5).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (6).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (7).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (8).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images (9).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/images.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/mag-0215-019-001-download.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/mainimage.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/maxresdefault (1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/maxresdefault.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/Passat_0109.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/resized-2010092805927505.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/ST_20150926_JCTPASS26_1707839.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/VOLKSWAGEN-PASSAT-00.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/Volkswagen-Passat-2.0TSI-Elegance-2020(1).jpg
#   inflating: Lab1dataset/data/train/Volkswagen/Volkswagen-Passat-2.0TSI-Elegance-2020.jpg
#  extracting: Lab1dataset/data/train/Volkswagen/volkswagen-passat-front-angle-low-view-434127.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/volkswagen-passat-sel-2020-02534.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/volkswagen_passat_18a_tsi_1569137414_b8b9585a_progressive.jpg
#   inflating: Lab1dataset/data/train/Volkswagen/volkswagen_passat_b8_20_tfsi_at_sr_3g24my_1545820195_afef663f_progressive.jpg
#    creating: Lab1dataset/data/validation/
#    creating: Lab1dataset/data/validation/Honda/
#   inflating: Lab1dataset/data/validation/Honda/4445456abb334947a58da81fe7bc34b1.jpg
#   inflating: Lab1dataset/data/validation/Honda/70005202163020091600100.jpg
#   inflating: Lab1dataset/data/validation/Honda/877136_2b.jpg
#   inflating: Lab1dataset/data/validation/Honda/912791_1.jpg
#   inflating: Lab1dataset/data/validation/Honda/921458_2.jpg
#   inflating: Lab1dataset/data/validation/Honda/b1.jpg
#   inflating: Lab1dataset/data/validation/Honda/b2.jpg
#   inflating: Lab1dataset/data/validation/Honda/b3.jpg
#  extracting: Lab1dataset/data/validation/Honda/b4.jpg
#   inflating: Lab1dataset/data/validation/Honda/b5.jpg
#   inflating: Lab1dataset/data/validation/Honda/Honda-Civic-LX-Manual-2019.png
#   inflating: Lab1dataset/data/validation/Honda/Honda-Civic-Sport-2020.jpg
#   inflating: Lab1dataset/data/validation/Honda/Honda-Civic-V-CVT-Petrol-2019.jpg
#   inflating: Lab1dataset/data/validation/Honda/Honda-Civic-ZX-CVT-Petrol-2019.jpg
#   inflating: Lab1dataset/data/validation/Honda/images (5).jpg
#   inflating: Lab1dataset/data/validation/Honda/resized-20190708170630002.jpg
#    creating: Lab1dataset/data/validation/Toyota/
#   inflating: Lab1dataset/data/validation/Toyota/5410ae_bcb1c15b7f644af29dd3170e0391e391_mv2.jpg
#   inflating: Lab1dataset/data/validation/Toyota/843433_1b.jpg
#   inflating: Lab1dataset/data/validation/Toyota/915638_1.jpg
#   inflating: Lab1dataset/data/validation/Toyota/9tro-altis-club-singapore-9.jpg
#   inflating: Lab1dataset/data/validation/Toyota/amazing2-2048x1170-dynamicjpg.jpg
#   inflating: Lab1dataset/data/validation/Toyota/b1.jpg
#   inflating: Lab1dataset/data/validation/Toyota/b2.jpg
#   inflating: Lab1dataset/data/validation/Toyota/b3.jpg
#   inflating: Lab1dataset/data/validation/Toyota/b4.jpg
#   inflating: Lab1dataset/data/validation/Toyota/b5.jpg
#   inflating: Lab1dataset/data/validation/Toyota/images (1).jpg
#   inflating: Lab1dataset/data/validation/Toyota/images (2).jpg
#   inflating: Lab1dataset/data/validation/Toyota/images (3).jpg
#   inflating: Lab1dataset/data/validation/Toyota/images (4).jpg
#   inflating: Lab1dataset/data/validation/Toyota/images.jpg
#    creating: Lab1dataset/data/validation/Volkswagen/
#   inflating: Lab1dataset/data/validation/Volkswagen/10980_m.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/2984.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/913131_2.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/924827_1.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/b1.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/b2.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/b3.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/b4.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/b5.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/images (1).jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/images (2).jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/images (3).jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/images.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/singapore_volkswagen_passat_carshoot_04.jpg
#   inflating: Lab1dataset/data/validation/Volkswagen/volkswagen_passat_18_tsi_1529818374_6c7c2913_progressive.jpg
#    creating: Lab1dataset/prediction_images/
#   inflating: Lab1dataset/prediction_images/honda1.jpg
#   inflating: Lab1dataset/prediction_images/honda2.jpg
#   inflating: Lab1dataset/prediction_images/honda3.jpg
#   inflating: Lab1dataset/prediction_images/honda4.jpg
#   inflating: Lab1dataset/prediction_images/honda5.jpg
#   inflating: Lab1dataset/prediction_images/toyota1.jpg
#   inflating: Lab1dataset/prediction_images/toyota2.jpg
#   inflating: Lab1dataset/prediction_images/toyota3.jpg
#   inflating: Lab1dataset/prediction_images/toyota4.jpg
#   inflating: Lab1dataset/prediction_images/toyota5.jpg
#   inflating: Lab1dataset/prediction_images/volkwagen1.jpg
#   inflating: Lab1dataset/prediction_images/volkwagen2.jpg
#  extracting: Lab1dataset/prediction_images/volkwagen3.jpg
#   inflating: Lab1dataset/prediction_images/volkwagen4.jpg
#  extracting: Lab1dataset/prediction_images/volkwagen5.jpg
#   inflating: Lab1dataset/prediction_images/volkwagen6.jpg
#   inflating: Lab1dataset/custom_w_supervision_try2.h5
#   inflating: Lab1dataset/custom_w_supervision_try2_best.h5

# %%
# !ls
# Out:
# Lab1dataset  Lab1dataset.zip  sample_data

# %% [markdown]
# We will define the following variables for the different data path.
#
# It will be easier for us to reference these paths in other sections of the code.

# %%
data_dir_path='Lab1dataset/'
train_data_dir = data_dir_path+'data/train/'
validation_data_dir = data_dir_path+'data/validation/'
prediction_data_dir = data_dir_path+'prediction_images/'

# %% [markdown]
# ### Exercise
# Let explore the images we had collected for the train dataset.
#
# Display the following images from the train data.
#
# * image 1 ( train_data_dir+"Honda/100.jpg")
# * image 2 (  train_data_dir+"Toyota/Altis.jpg")
#
# What do you notice about the size of each of the image?
# Read the printed image size ( height,width, color).
#
# *color(1-greysacle, 3-color)
#
# Why are we interested in the image size?
#
# <details><summary>Click here for answer</summary>
# <br/>
#
# When we build a Convolution Neural Network(CNN), we usually specify a fixed input size. Therefore we need to pre-process the collected images to the same size as the expected input before we can do training.
#
# <br/>
# </details>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# TODO: complete the code below
#image 1
# img = mpimg.imread(#add code)
img = mpimg.imread( train_data_dir+"Honda/100.jpg")
print(img.shape)
imgplot = plt.imshow(img)
# Out:
# (1413, 2700, 3)

# %%
# TODO: complete the code below
#image 2
# img = mpimg.imread(#add code)
img = mpimg.imread(train_data_dir+"Toyota/Altis.jpg")
print(img.shape)
imgplot = plt.imshow(img)
# Out:
# (2480, 2480, 3)

# %% [markdown]
# ### 3.2 Prepare Data for training and validation
#
# From the previous exercise, we noticed that the collected data need to be pre-processed before we can use it to train our CNN. In this section, we will look at some of the methods that can help us to do data pre-processing.
#
# Data augmentation is a strategy that enables developer to significantly increase the diversity of data available through data pre-processing.
#
# Data augmentation techniques such as resizing, rotation, and cropping are commonly used to train large neural networks.
#
#
# ![image](https://drive.google.com/uc?id=1Y1V7I79GthoHvqjVYfgaCZHloDh1VZ2z)
#
# Kera provides us a function to do data augmentation. We can configure the parameters in the function to achieve the required image pre-processing. We will do some of the parameters configuration in the exercise.

# %% [markdown]
# ### Exercise
# We will configure the image augmentation parameters in the Keras ImageDataGenerator() function for the train and validation data.
#
# Here are some for the parameters.
#
# - rescale factor. Defaults to None. If None or 0, no rescaling is applied, otherwise we multiply the data by the value provided. For training neural network, we usually want to keep our values small (e.g. between 0 and 1.0) so that the network can be more stable and converge faster.
#
# - shear_range: Float. Shear Intensity (Shear angle in counter-clockwise direction in degrees) eg. 0.2 degrees
#
# - zoom_range: Float. zoom range for width and height. eg. 0.2
#
# - horizontal_flip: Boolean. Randomly flip inputs horizontally.eg. True
#
# Set the appropriate parameter values in the following codes marked with #add code
#
#
# Also examine the parameter *target_size* in the function train_datagen.flow_from_directory() and validation_datagen.flow_from_directory.
#
# What is the target_size we need to choose for the data pre-processing?
# <details><summary>Click here for answer</summary>
# <br/>
#
# As mentioned previously, we usually specify an expected fixed data input size when we build a CNN. Therefore we need to set the target_size to be the same as the expected input size for pre-processing. How do we know the expected size? We will find out in the following section when we setup our CNN.
#
# <br/>
# </details>
#
# <br/>
#
# We will put the above pre-processing steps for train and validation inside the function name PrepareData().

# %%
#Prepare Data for training and validation

def PrepareData(img_width,img_height,batch_size ):

    # This augments the data. This is usefull when working with a small sample size
    # TODO: complete the code below
    train_datagen = ImageDataGenerator(
        rescale= 1./255,
        shear_range= 0.2,
        zoom_range= 0.2,
        horizontal_flip= True)

    # TODO: complete the code below
    validation_datagen = ImageDataGenerator(rescale=1./255)

    print("train generator")
    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    print("validation generator")
    validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True)

    return train_generator,validation_generator

# %% [markdown]
# ### 3.3 Get the total number of predicted classes/labels
#
# The label of the training samples are determined by the subdirectory name, e.g.In the train sub-directories, Honda is the label to tag to all the images collected for that group.
#
# In our case, the number of predicted classes (or labels) are based on the numbers of sub-directories in the train folder.

# %% [markdown]
# ### Exercise
# We are going to find the number of classes and the labels for our collected data.
#
# Where can we get the information for the number of classes and the Label names?
# Look for the directory where we stored our train data. Complete the following code.
#
# Observe the number of classes printed at the output. Why the number of classes is 3?
# <details><summary>Click here for answer</summary>
# <br/>
# In our classification problem, we need to classify three types of cars. Therefore the classes is defined to be 3.
#
# The number of classes is to allow the CNN to predict the number of outputs.
#
# <br/>
# </details>

# %%
# Gets the total no. of classes and labels

# TODO: complete the code below -what is the directory of the train data
classes = ImageDataGenerator().flow_from_directory(train_data_dir).class_indices
print(classes)
print("number of classes="+ str(len(classes)))
num_classes = len(classes)
# Out:
# Found 193 images belonging to 3 classes.
# {'Honda': 0, 'Toyota': 1, 'Volkswagen': 2}
# number of classes=3

# %% [markdown]
# # 4. Prepare the CNN Model

# %% [markdown]
# ### 4.1 CNN Convolution Netural Network
#
#
# ![image](https://drive.google.com/uc?id=1TvHHScdeRsKcQTNiVpbKu1lUnJlLQLim)
#
# There are many CNN implementation, such as LeNet, AlexNet, VGG, GoogLeNet, ResNet and more.
#
# In this lab we will be using ResNet50 CNN.
#
# The ResNet50 is built from the different combination of the following layers
#
#         *   Conv2D-> number of feature maps, feature map size (width x height)
#         *   Activation function -> relu , sigmoid
#         *   MaxPooling-> kernel size (width x height)
#
# together with the output layers
#
#         *   Flatten-> 2D to 1D
#         *   Dense layer->number of neutrons
#         *   Activation Function->softmax(probability of each the classes)

# %% [markdown]
# ### Execrise
# We have a brief understanding of how the ResNet50 layers are formed. In this exercise, we will customise our ResNet50 to train our pre-process dataset.
#
# Assuming we want to have input image size of (197, 197, 3) (height, width, channels). In the code below, change the function ResNet50() to have the the specified input size.
#
# - In the following code, goto function ResNet50() set the parameters input_size to (width,height,color)->(197,197,3)
#
# Based on the number of classes we have discuss in the previous exercise 3.3, what do you think is the number of neurons required in the output Dense layer?
#
# - Add the number of neurons required in the output Dense layer?
#
#
# Run the function compileModel() to build the custom ResNet50.
#
# Observe the print out of the ResNet50 layers. What have we customised in our ResNet50 CNN?
#
# <details><summary>Click here for answer</summary>
# <br/>
#
# We have setted our customise ResNet50 with the input size (197,197,3), and output to be (3)
#
#
# <br/>
# </details>

# %%
def compileModel():

    print("compiling model")
    learning_rate=1e-4

     ## TODO: Add in the input size
    conv_base = ResNet50(weights='imagenet',
                      include_top=False,
                      input_shape=(197, 197, 3))

    model = models.Sequential()
    model.add(conv_base)
    #Add dense and classification layer
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.2))


    ## TODO: Change the Output Dense layer to have the correct number of neurons
    model.add(layers.Dense(num_classes, activation='softmax'))

    print(conv_base.summary())
    print(model.summary())

    model.compile(loss='categorical_crossentropy',optimizer= optimizers.Adam(lr=learning_rate),metrics=['accuracy'])
    for layer in conv_base.layers:
      layer.trainable = False
    for layer in conv_base.layers[-4:]:
      layer.trainable = True
    return model

# %%
compileModel()
# Out:
# compiling model
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 197, 197, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 203, 203, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 99, 99, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 99, 99, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 99, 99, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 101, 101, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 50, 50, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 50, 50, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 50, 50, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 50, 50, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 50, 50, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 50, 50, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 50, 50, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 25, 25, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 25, 25, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 25, 25, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 25, 25, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 25, 25, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 25, 25, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 25, 25, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 25, 25, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 13, 13, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 13, 13, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
# None
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 49311363 (188.11 MB)
# Trainable params: 49258243 (187.91 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None

# %% [markdown]
# # 5. Train the model with the training set and evaluate it performance

# %% [markdown]
# ### 5.1 Train and validate the model
#
#
# ![image](https://drive.google.com/uc?id=1E4kipAQNfq9vKY-cNRmb_y2Dj_t4gfBN)
#
# With the preprocessed training and validation dataset and our defined model. We can start to preform the training process.
# As part of the training, we will also need to set some parameter values in the training function (the ``fit()``)
#
# - Set the number of epoch to  indicates the number of passes of the entire training dataset the model has to complete.
#
# - When we have a huge data set it not possible to load the entire data to run one epoch of training. Setting Step per epoch allow huge data to divide into batches to complete entire training.
#
# We save the final training iteration weights into to a binary data format(.h5).
#
# In the trainModel() function it will save the final iteration weights into a file "custom_w_supervision_try2.h5".
# We also set a ModelCheckpoint() function to monitor the validation accuracy in each of the training iterations. This function will save the weights into a file "custom_w_supervision_try2_best.h5" with the best validation accuracy.

# %%
best_model = tensorflow.keras.callbacks.ModelCheckpoint(data_dir_path+'custom_w_supervision_try2_best.h5', monitor='val_loss',save_best_only=True,save_weights_only=False,verbose=1, mode='min')
reduce_lr = tensorflow.keras.callbacks.ReduceLROnPlateau(monitor='loss',factor=0.25, patience=5,min_lr=0.000005)


def trainModel(train_data, validation_data,model):

    print("starting training.... ")
    hist = model.fit_generator(
        (train_data),
        steps_per_epoch=nb_train_samples // batch_size, # The accumulated amount of steps
        epochs=epochs,
        validation_data=validation_data,
        # nb_val_samples=nb_validation_samples,
        callbacks=[best_model]
    )

    plotVal_plotLoss(hist)
    model.save_weights(data_dir_path+'custom_w_supervision_try2.h5') # Saving the compile weights

# %% [markdown]
# This following function plotVal_plotLoss() is to plot the accuracy and loss result of the model during the training.
#
# - Loss is a number that indicates the difference between the model's prediction output with the ground truth.
#
# - Accuracy is a metric that can be applied to classification tasks only. It describes just what percentage of your train/test data are classified correctly.

# %%
# This function generates graphs of the loss and the accuracy of the model
def plotVal_plotLoss (model) :

    plt.plot(model.history['accuracy'])
    plt.plot(model.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('loss_plot_4 (simulated vgg1)2')
    plt.show()

    plt.plot(model.history['loss'])
    plt.plot(model.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('loss_plot_4 (simulated vgg1)2')
    plt.show()

# %% [markdown]
# ### Exercise
#
# Now we are ready to start the training process.
#
# From section 4.1 exercise, we have set the ResNet50 input size. We preprocess our data to the same width and height before it can be used for the training.
#
# - Set the PrepareData() with the correct ``image_height`` and ``Image_width``
# <details><summary>Click here for answer</summary>
# <br/>
#         image_height=197
#         Image_width=197
# <br/>
# </details>
#
#
# Set the number of epoch(iterations) to conduct the training
#
# - At the  variable epochs set a number(integer number)
#
#
# The trainModel() function will start the training.
#
# - Since we have 180 samples, and we are using a batch size of 2, how many training steps are required to go through all the samples? Observe the training output and see whether the number of steps is the same as your answer.
# <details><summary>Click here for answer</summary>
# <br/>
#      Step per ecoph = 90
# <br/>
# </details>
#
#
# You can vary the epochs to observe the model accuracy and loss values.
#
# - What do you notice when epochs are varied?
# <details><summary>Click here for answer</summary>
# <br/>
# Typically the increase in the epochs will reduce the loss and improve the prediction accuracy.
#
# <br/>
# </details>

# %%
# dimensions of our images.
## TODO: Set the image width and height
img_width, img_height = 197,197

# The batch size represents the total amount of pictures that are included in each iteration.
## TODO: Set the batch size
batch_size = 2

#Prepare data
train_data, validation_data = PrepareData(img_width,img_height,batch_size)

#Load Model
model=compileModel()

# Defining the total amount of samples in both the training and validation set
nb_train_samples =180
nb_validation_samples =45

## TODO: Set the number to training iterations
epochs = 50

#Start the training model
trainModel(train_data, validation_data, model)
# Out:
# train generator
# Found 193 images belonging to 3 classes.
# validation generator
# Found 46 images belonging to 3 classes.
# compiling model
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 197, 197, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 203, 203, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 99, 99, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 99, 99, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 99, 99, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 101, 101, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 50, 50, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 50, 50, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 50, 50, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 50, 50, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 50, 50, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 50, 50, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 50, 50, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 25, 25, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 25, 25, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 25, 25, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 25, 25, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 25, 25, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 25, 25, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 25, 25, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 25, 25, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 13, 13, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 13, 13, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
# ...
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_3 (Dense)             (None, 256)               25690368
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 49311363 (188.11 MB)
# Trainable params: 49258243 (187.91 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None
# starting training....
# <ipython-input-12-6600f26d5bb6>:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(
# Epoch 1/50
# 90/90 [==============================] - ETA: 0s - loss: 8.0352 - accuracy: 0.2961
# Epoch 1: val_loss improved from inf to 2.09542, saving model to Lab1dataset/custom_w_supervision_try2_best.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 90/90 [==============================] - 54s 118ms/step - loss: 8.0352 - accuracy: 0.2961 - val_loss: 2.0954 - val_accuracy: 0.3261
# Epoch 2/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2564 - accuracy: 0.3631
# Epoch 2: val_loss improved from 2.09542 to 1.20019, saving model to Lab1dataset/custom_w_supervision_try2_best.h5
# 90/90 [==============================] - 9s 104ms/step - loss: 1.2564 - accuracy: 0.3631 - val_loss: 1.2002 - val_accuracy: 0.3261
# Epoch 3/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2048 - accuracy: 0.3575
# Epoch 3: val_loss did not improve from 1.20019
# 90/90 [==============================] - 6s 66ms/step - loss: 1.2048 - accuracy: 0.3575 - val_loss: 1.3918 - val_accuracy: 0.3261
# Epoch 4/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2409 - accuracy: 0.3520
# Epoch 4: val_loss did not improve from 1.20019
# 90/90 [==============================] - 7s 75ms/step - loss: 1.2409 - accuracy: 0.3520 - val_loss: 1.4728 - val_accuracy: 0.3261
# Epoch 5/50
# 90/90 [==============================] - ETA: 0s - loss: 1.5242 - accuracy: 0.3464
# Epoch 5: val_loss improved from 1.20019 to 1.09460, saving model to Lab1dataset/custom_w_supervision_try2_best.h5
# 90/90 [==============================] - 10s 113ms/step - loss: 1.5242 - accuracy: 0.3464 - val_loss: 1.0946 - val_accuracy: 0.3696
# Epoch 6/50
# 90/90 [==============================] - ETA: 0s - loss: 1.4368 - accuracy: 0.2737
# Epoch 6: val_loss did not improve from 1.09460
# 90/90 [==============================] - 6s 62ms/step - loss: 1.4368 - accuracy: 0.2737 - val_loss: 1.1349 - val_accuracy: 0.3261
# Epoch 7/50
# 90/90 [==============================] - ETA: 0s - loss: 1.3360 - accuracy: 0.3464
# Epoch 7: val_loss improved from 1.09460 to 1.03958, saving model to Lab1dataset/custom_w_supervision_try2_best.h5
# 90/90 [==============================] - 13s 146ms/step - loss: 1.3360 - accuracy: 0.3464 - val_loss: 1.0396 - val_accuracy: 0.4565
# Epoch 8/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1661 - accuracy: 0.3799
# Epoch 8: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.1661 - accuracy: 0.3799 - val_loss: 1.1926 - val_accuracy: 0.2826
# Epoch 9/50
# 90/90 [==============================] - ETA: 0s - loss: 1.3548 - accuracy: 0.3464
# Epoch 9: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.3548 - accuracy: 0.3464 - val_loss: 25.5401 - val_accuracy: 0.3913
# Epoch 10/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2897 - accuracy: 0.3464
# Epoch 10: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.2897 - accuracy: 0.3464 - val_loss: 1.7048 - val_accuracy: 0.2826
# Epoch 11/50
# 90/90 [==============================] - ETA: 0s - loss: 1.3895 - accuracy: 0.3184
# Epoch 11: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.3895 - accuracy: 0.3184 - val_loss: 1.1492 - val_accuracy: 0.3913
# Epoch 12/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2924 - accuracy: 0.3128
# Epoch 12: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.2924 - accuracy: 0.3128 - val_loss: 1.2894 - val_accuracy: 0.3478
# Epoch 13/50
# 90/90 [==============================] - ETA: 0s - loss: 1.4155 - accuracy: 0.3128
# Epoch 13: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.4155 - accuracy: 0.3128 - val_loss: 2.1880 - val_accuracy: 0.2826
# Epoch 14/50
# 90/90 [==============================] - ETA: 0s - loss: 1.4364 - accuracy: 0.3073
# Epoch 14: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 66ms/step - loss: 1.4364 - accuracy: 0.3073 - val_loss: 2.6946 - val_accuracy: 0.3261
# Epoch 15/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2970 - accuracy: 0.2961
# Epoch 15: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 76ms/step - loss: 1.2970 - accuracy: 0.2961 - val_loss: 1.6851 - val_accuracy: 0.3043
# Epoch 16/50
# 90/90 [==============================] - ETA: 0s - loss: 1.4717 - accuracy: 0.3966
# Epoch 16: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 61ms/step - loss: 1.4717 - accuracy: 0.3966 - val_loss: 11065.2832 - val_accuracy: 0.3261
# Epoch 17/50
# 90/90 [==============================] - ETA: 0s - loss: 2.5974 - accuracy: 0.4637
# Epoch 17: val_loss did not improve from 1.03958
# 90/90 [==============================] - 8s 85ms/step - loss: 2.5974 - accuracy: 0.4637 - val_loss: 16868.5586 - val_accuracy: 0.3261
# Epoch 18/50
# 90/90 [==============================] - ETA: 0s - loss: 2.4008 - accuracy: 0.3799
# Epoch 18: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 61ms/step - loss: 2.4008 - accuracy: 0.3799 - val_loss: 355.9185 - val_accuracy: 0.3261
# Epoch 19/50
# 90/90 [==============================] - ETA: 0s - loss: 1.6514 - accuracy: 0.4078
# Epoch 19: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 79ms/step - loss: 1.6514 - accuracy: 0.4078 - val_loss: 667.7629 - val_accuracy: 0.3261
# Epoch 20/50
# 90/90 [==============================] - ETA: 0s - loss: 1.3455 - accuracy: 0.3855
# Epoch 20: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 70ms/step - loss: 1.3455 - accuracy: 0.3855 - val_loss: 6.6966 - val_accuracy: 0.4348
# Epoch 21/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2325 - accuracy: 0.3575
# Epoch 21: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 72ms/step - loss: 1.2325 - accuracy: 0.3575 - val_loss: 19.2686 - val_accuracy: 0.4348
# Epoch 22/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1373 - accuracy: 0.4246
# Epoch 22: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 79ms/step - loss: 1.1373 - accuracy: 0.4246 - val_loss: 8.9350 - val_accuracy: 0.4565
# Epoch 23/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1794 - accuracy: 0.3631
# Epoch 23: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 63ms/step - loss: 1.1794 - accuracy: 0.3631 - val_loss: 3.4864 - val_accuracy: 0.4348
# Epoch 24/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1446 - accuracy: 0.3855
# Epoch 24: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 68ms/step - loss: 1.1446 - accuracy: 0.3855 - val_loss: 1.9070 - val_accuracy: 0.4783
# Epoch 25/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1663 - accuracy: 0.3631
# Epoch 25: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 64ms/step - loss: 1.1663 - accuracy: 0.3631 - val_loss: 4.1383 - val_accuracy: 0.4130
# Epoch 26/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1293 - accuracy: 0.3743
# Epoch 26: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 77ms/step - loss: 1.1293 - accuracy: 0.3743 - val_loss: 3.5499 - val_accuracy: 0.4783
# Epoch 27/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1093 - accuracy: 0.4134
# Epoch 27: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 81ms/step - loss: 1.1093 - accuracy: 0.4134 - val_loss: 27.5387 - val_accuracy: 0.3261
# Epoch 28/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1679 - accuracy: 0.4246
# Epoch 28: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.1679 - accuracy: 0.4246 - val_loss: 29.9158 - val_accuracy: 0.3261
# Epoch 29/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2697 - accuracy: 0.3631
# Epoch 29: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 63ms/step - loss: 1.2697 - accuracy: 0.3631 - val_loss: 6.7316 - val_accuracy: 0.3913
# Epoch 30/50
# 90/90 [==============================] - ETA: 0s - loss: 1.2153 - accuracy: 0.3778
# Epoch 30: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.2153 - accuracy: 0.3778 - val_loss: 4.9259 - val_accuracy: 0.2391
# Epoch 31/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1771 - accuracy: 0.4078
# Epoch 31: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 71ms/step - loss: 1.1771 - accuracy: 0.4078 - val_loss: 1.1760 - val_accuracy: 0.4348
# Epoch 32/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1106 - accuracy: 0.3743
# Epoch 32: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.1106 - accuracy: 0.3743 - val_loss: 1.3070 - val_accuracy: 0.3696
# Epoch 33/50
# 90/90 [==============================] - ETA: 0s - loss: 1.0865 - accuracy: 0.4078
# Epoch 33: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 61ms/step - loss: 1.0865 - accuracy: 0.4078 - val_loss: 5.3088 - val_accuracy: 0.3696
# Epoch 34/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1711 - accuracy: 0.4302
# Epoch 34: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.1711 - accuracy: 0.4302 - val_loss: 1.8612 - val_accuracy: 0.3478
# Epoch 35/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.3855
# Epoch 35: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 72ms/step - loss: 1.1180 - accuracy: 0.3855 - val_loss: 1.3571 - val_accuracy: 0.4130
# Epoch 36/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1378 - accuracy: 0.3575
# Epoch 36: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.1378 - accuracy: 0.3575 - val_loss: 1.0928 - val_accuracy: 0.4130
# Epoch 37/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1649 - accuracy: 0.3687
# Epoch 37: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 65ms/step - loss: 1.1649 - accuracy: 0.3687 - val_loss: 1.1289 - val_accuracy: 0.3261
# Epoch 38/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1604 - accuracy: 0.3855
# Epoch 38: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 65ms/step - loss: 1.1604 - accuracy: 0.3855 - val_loss: 4.7478 - val_accuracy: 0.3478
# Epoch 39/50
# 90/90 [==============================] - ETA: 0s - loss: 1.0893 - accuracy: 0.4022
# Epoch 39: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.0893 - accuracy: 0.4022 - val_loss: 1.1380 - val_accuracy: 0.3261
# Epoch 40/50
# 90/90 [==============================] - ETA: 0s - loss: 1.0946 - accuracy: 0.3944
# Epoch 40: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 61ms/step - loss: 1.0946 - accuracy: 0.3944 - val_loss: 1.0937 - val_accuracy: 0.3913
# Epoch 41/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1020 - accuracy: 0.3911
# Epoch 41: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 75ms/step - loss: 1.1020 - accuracy: 0.3911 - val_loss: 1.1144 - val_accuracy: 0.3043
# Epoch 42/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1336 - accuracy: 0.3631
# Epoch 42: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.1336 - accuracy: 0.3631 - val_loss: 1.2741 - val_accuracy: 0.4130
# Epoch 43/50
# 90/90 [==============================] - ETA: 0s - loss: 1.0840 - accuracy: 0.3520
# Epoch 43: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.0840 - accuracy: 0.3520 - val_loss: 1.1107 - val_accuracy: 0.3261
# Epoch 44/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1213 - accuracy: 0.3743
# Epoch 44: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 70ms/step - loss: 1.1213 - accuracy: 0.3743 - val_loss: 1.1185 - val_accuracy: 0.3043
# Epoch 45/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1087 - accuracy: 0.3743
# Epoch 45: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 62ms/step - loss: 1.1087 - accuracy: 0.3743 - val_loss: 1.1550 - val_accuracy: 0.2826
# Epoch 46/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1117 - accuracy: 0.3855
# Epoch 46: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 82ms/step - loss: 1.1117 - accuracy: 0.3855 - val_loss: 1.0979 - val_accuracy: 0.3261
# Epoch 47/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1093 - accuracy: 0.3408
# Epoch 47: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 65ms/step - loss: 1.1093 - accuracy: 0.3408 - val_loss: 1.4546 - val_accuracy: 0.2826
# Epoch 48/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1223 - accuracy: 0.3667
# Epoch 48: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 82ms/step - loss: 1.1223 - accuracy: 0.3667 - val_loss: 3.3612 - val_accuracy: 0.2826
# Epoch 49/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1188 - accuracy: 0.3556
# Epoch 49: val_loss did not improve from 1.03958
# 90/90 [==============================] - 7s 80ms/step - loss: 1.1188 - accuracy: 0.3556 - val_loss: 5.0804 - val_accuracy: 0.2826
# Epoch 50/50
# 90/90 [==============================] - ETA: 0s - loss: 1.1092 - accuracy: 0.3500
# Epoch 50: val_loss did not improve from 1.03958
# 90/90 [==============================] - 6s 63ms/step - loss: 1.1092 - accuracy: 0.3500 - val_loss: 1.3228 - val_accuracy: 0.2826

# %% [markdown]
# # 6. Use the trained model to classify input data

# %% [markdown]
# ### 6.1 Setup a predict image function
#
# After completed the training for the customised ResNet50 CNN model. The following predictImg() function will use the trained model to predict the output of an unknown image.

# %%
def predictImg(path,img_width,img_height ,model):
    imagep = image.load_img(path, target_size=(img_width, img_height))
    x = image.img_to_array(imagep)
    x = x / 255  # Insures that images are normalized, so it can be compared test on a model that also used normalized training and validation images

    x = np.expand_dims(x, axis=0) # flattens the image
    prediction = model.predict(x) # Extract the prediction made by the model
    print(path)
    print(prediction)
    findLabel(prediction, 0.2, path)

# %%
def findLabel(test, threshold, path):
    if (max(test[0]) < threshold):
        print("no class could be defined for " + path + " with threshold 0.85")
    else:
        m = max(test[0])
        index = [i for i, j in enumerate(list(test[0])) if j == m]
        #labeler(index[0], path)
        label = list(classes.keys())[index[0]]
        print("The image '" + path + "' belongs to class: " + label) # Prints the prediction

# %% [markdown]
# ### Exercise
#
# Now we are ready to use the trained model to predict the image.
#
# First we need to load our Resnet50 CNN model with the trained weights.
# - During traning fit() function call the ModelCheckPoint() to monitor and save the weights with best validation accuracy. Find where is the directory and file name for best weights file. Input into the model.load_weights() function in the following code.
# <details><summary>Click here for answer</summary>
# <br/>
# data_dir_path+'custom_w_supervision_try2_best.h5'
# <br/>
# </details>
#
#
# Next we need to specify an unknown images file for prediction.
# - Find a test image file in the directory './Lab1dataset/prediction_images/' pass into  predictImg() function
# <details><summary>Click here for answer</summary>
# <br/>
#     eg.    prediction_data_dir+"honda1.jpg"
# <br/>
# </details>
#
# Try to load different test images to predict the output. You can check the predicted label against the test image file name. The test image file name is the ground truth label.

# %%
# # np.set_printoptions(suppress=True, precision=3)

model = compileModel()

## TODO: Set the best-trained weigth dir and file name
model.load_weights(data_dir_path+"custom_w_supervision_try2.h5")
# Out:
# compiling model
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 197, 197, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 203, 203, 3)          0         ['input_3[0][0]']
#
#  conv1_conv (Conv2D)         (None, 99, 99, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 99, 99, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 99, 99, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 101, 101, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 50, 50, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 50, 50, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 50, 50, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 50, 50, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 50, 50, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 50, 50, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 50, 50, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 50, 50, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 50, 50, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 50, 50, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 50, 50, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 50, 50, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 50, 50, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 50, 50, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 25, 25, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 25, 25, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 25, 25, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 25, 25, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 25, 25, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 25, 25, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 25, 25, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 25, 25, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 25, 25, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 25, 25, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 25, 25, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 25, 25, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 25, 25, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 25, 25, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 25, 25, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 13, 13, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 13, 13, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 13, 13, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 13, 13, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 13, 13, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 13, 13, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 13, 13, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 13, 13, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 13, 13, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 13, 13, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
# None
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_6 (Dense)             (None, 256)               25690368
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 49311363 (188.11 MB)
# Trainable params: 49258243 (187.91 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# None

# %%
## TODO: Set the unknown image dir and file name
predictImg(prediction_data_dir+"honda3.jpg", 197, 197 , model)
# Out:
# 1/1 [==============================] - 1s 928ms/step
# Lab1dataset/prediction_images/honda3.jpg
# [[0.30217972 0.3260794  0.3717409 ]]
# The image 'Lab1dataset/prediction_images/honda3.jpg' belongs to class: Volkswagen

# %%
model_best =tensorflow.keras.models.load_model(data_dir_path+"custom_w_supervision_try2_best.h5")

# %%
## TODO: Set the unknown image dir and file name
predictImg(prediction_data_dir+"honda3.jpg", 197, 197 , model_best)
# Out:
# 1/1 [==============================] - 1s 895ms/step
# Lab1dataset/prediction_images/honda3.jpg
# [[0.40734592 0.39657006 0.19608404]]
# The image 'Lab1dataset/prediction_images/honda3.jpg' belongs to class: Honda
